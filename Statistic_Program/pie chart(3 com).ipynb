# %%
#1,2,3種組合 分3種
import pandas as pd
import xlrd ,xlwt
import numpy
# #讀        
data_name='seqGAN_output_hs5TLL_0608_type2.xls'


df = pd.read_excel('C://Users/lilly/Desktop/HiSeqGan-master/seqganoutput0608/'+data_name)


attack=0
defence=0
others=0
for i in range(0,100):
    rownum=numpy.sum(df[i:i+1].count(axis =1))
    #
    for j in range(2,rownum):

        
        #num of tag 3
        tag1=df.iloc[i,j-2] 
        tag2=df.iloc[i,j-1]
        tag3=df.iloc[i,j] 
        if(((tag1 == 'Clear')or(tag1 == 'Drive')or(tag1 == 'Net_lift')or(tag1 == 'Dribble')or(tag1 == 'Defensive_short'))and((tag2 == 'Clear')or(tag2 == 'Drive')or(tag2 == 'Net_lift')or(tag2 == 'Dribble')or(tag2 == 'Defensive_short'))and((tag3 == 'Clear')or(tag3 == 'Drive')or(tag3 == 'Net_lift')or(tag3 == 'Dribble')or(tag3 == 'Defensive_short'))):
             defence=defence+1
#              print(1)
        elif(((tag1 == 'Net_smash')or(tag1 == 'Drop')or(tag1 == 'Smash')or(tag1 == 'Net'))and((tag2 == 'Net_smash')or(tag2 == 'Drop')or(tag2 == 'Smash')or(tag2 == 'Net'))and((tag3 == 'Net_smash')or(tag3 == 'Drop')or(tag3 == 'Smash')or(tag3 == 'Net'))):    
             attack=attack+1
        else:
             others=others+1
                

all=attack+defence+others
# print(defence)
alldict={}
dict={'Attack':round(attack/all,3)}
alldict={**alldict,**dict}
dict={'Defense':round(defence/all,3)}
alldict={**alldict,**dict}
dict={'Combined':round(others/all,3)}
alldict={**alldict,**dict}
alldict
# Out:
# {'Attack': 0.019, 'Combined': 0.777, 'Defense': 0.204}

# %%
import pandas as pd               # 資料處理套件
import matplotlib.pyplot as plt   # 資料視覺化套件

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOTT_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOTC_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOCT_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOCC_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1WW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1WL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1LW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1LL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2WW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2WL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2LW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2LL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3WW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3WL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3LW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3LL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4WW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4WL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4LW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4LL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5WW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5WL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5LW_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Attack','Defense','Combined']
labels=['Att','Def','Com']
size=[alldict['Attack'],alldict['Defense'],alldict['Combined']]
colors=['dimgray','lightgray','darkgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("HSBCDAY5_2(server:winner=Tai:Tai)", {"fontsize" : 24})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5LL_3b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊
