# %%
#要挑出戴資營打的球
#1,2,3種組合
import pandas as pd
import xlrd ,xlwt
import numpy
# #讀        
# data_name='seqGAN_output_tkCC_0608_type2.xls'

data_name='seqGAN_output_hs5TLL_0608_type2.xls'

df = pd.read_excel('C://Users/lilly/Desktop/HiSeqGan-master/seqganoutput0608/'+data_name)


# 總元素組合個數=1
allnum=0
allnum=numpy.sum(df.count(axis =1))

# #總元素組合個數=2
# allnum=0
# for a in range(0,100):
#     row=numpy.sum(df[a:a+1].count(axis =1))
#     for b in range(1,row):
#         #num of tag
#         allnum=allnum+1
        
#總元素組合個數=3
# allnum=0
# for a in range(0,100):
#     row=numpy.sum(df[a:a+1].count(axis =1))
#     for b in range(2,row):
#         #num of tag
#         allnum=allnum+1     
        
print(allnum)
############################
alldicttest={}
for i in range(0,100):
    rownum=numpy.sum(df[i:i+1].count(axis =1))
    #
    for j in range(0,rownum):
        
        #num of tag 1
        tag=df.iloc[i,j]
        
#         #num of tag 2
#         tag=df.iloc[i,j-1] +" "+df.iloc[i,j] 
        

#         #num of tag 3
#         tag=df.iloc[i,j-2] +" "+df.iloc[i,j-1] +" "+df.iloc[i,j] 
        
        count=0
        for k in range(0,100):
            rownum2=numpy.sum(df[k:k+1].count(axis =1))
            #
            for q in range(0,rownum2):
                 #num of tag 1
                temp=df.iloc[k,q]
                
#                 #num of tag 2
#                 temp=df.iloc[k,q-1] +" "+df.iloc[k,q] 

#                 #num of tag 3
#                 temp=df.iloc[k,q-2] +" "+df.iloc[k,q-1] +" "+df.iloc[k,q] 
                
                if temp== tag:
                    count=count+1
        dict={tag:round(count/allnum,3)}
        alldicttest={**alldicttest,**dict}
# Out:
# 429

# %%
#暫時畫圖
import pandas as pd               # 資料處理套件
import matplotlib.pyplot as plt   # 資料視覺化套件

labels=['win','lose']
size=[96/192,96/192]
colors=['dimgray','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})

for t in L_text:
    t.set_size(35)
    
# for i in range(len(p_text)):
#     if i==0:
#         L_text[i].set_y(0.2)
#         p_text[i].set_y(0.1)
#         p_text[i].set_x(0.8)
#     if i==1:
#         L_text[i].set_y(0.6)
#         p_text[i].set_y(0.3)

# #     if i==:
# #         p_text[i].set_x(0.3)
#     if i==7:
# #         L_text[i].set_y(1.1)
#         L_text[i].set_y(-0.25)
#         p_text[i].set_y(-0.1)
#         p_text[i].set_x(0.8)
            
#     if i==8:
#         p_text[i].set_x(0.4)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("HSBCDAY5battack.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊
# print(151/303)

# %%
import pandas as pd               # 資料處理套件
import matplotlib.pyplot as plt   # 資料視覺化套件

# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==0:
        L_text[i].set_y(0.2)
        p_text[i].set_y(0.1)
        p_text[i].set_x(0.8)
    if i==1:
        L_text[i].set_y(0.6)
        p_text[i].set_y(0.3)

#     if i==:
#         p_text[i].set_x(0.3)
    if i==7:
#         L_text[i].set_y(1.1)
        L_text[i].set_y(-0.25)
        p_text[i].set_y(-0.1)
        p_text[i].set_x(0.8)
            
    if i==8:
        p_text[i].set_x(0.4)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOTT_1.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25}) 

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==0:
        L_text[i].set_y(0.2)
        p_text[i].set_y(0.1)
        p_text[i].set_x(0.8)
    if i==1:
        L_text[i].set_y(0.6)
        p_text[i].set_y(0.3)

#     if i==:
#         p_text[i].set_x(0.3)
    if i==7:
#         L_text[i].set_y(1.1)
#         L_text[i].set_y(-0.25)
#         p_text[i].set_y(-0.1)
        p_text[i].set_x(0.2)
            
#     if i==8:
#         p_text[i].set_x(0.4)

plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOTC_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==0:
        L_text[i].set_y(0.2)
        p_text[i].set_y(0.1)
        p_text[i].set_x(0.8)
    if i==1:
        L_text[i].set_y(0.6)
        p_text[i].set_y(0.3)

    if i==4:
        p_text[i].set_y(-0.4)
    if i==7:
        p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOCT_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
# for i in range(len(p_text)):
# #     if i==1:
# #         L_text[i].set_y(0.8)
# #         L_text[i].set_x(0.8)
# #         p_text[i].set_y(0.7)
# #         p_text[i].set_x(0.5)
#     if i==2:
#         L_text[i].set_y(1)
#         p_text[i].set_y(0.7)
#         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/TOKYOCC_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})

for t in L_text:
    t.set_size(35)
    
# for i in range(len(p_text)):
# #     if i==1:
# #         L_text[i].set_y(0.8)
# #         L_text[i].set_x(0.8)
# #         p_text[i].set_y(0.7)
# #         p_text[i].set_x(0.5)
#     if i==2:
#         L_text[i].set_y(1)
#         p_text[i].set_y(0.7)
#         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1WW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==1:
#         L_text[i].set_y(0.8)
#         L_text[i].set_x(0.8)
#         p_text[i].set_y(0.7)
#         p_text[i].set_x(0.5)
    if i==6:
        L_text[i].set_x(0.4)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1WL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==1:
#         L_text[i].set_y(1.7)
#         L_text[i].set_x(0.8)
        p_text[i].set_y(0.7)
        p_text[i].set_x(0.4)
    if i==6:
        L_text[i].set_x(0.4)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1LW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==2:
        p_text[i].set_y(0.65)
        L_text[i].set_x(0.2)
        L_text[i].set_y(1.1)
#     if i==1:
#         L_text[i].set_y(1.1)
#         p_text[i].set_y(0.8)
#         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY1LL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})    

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==5:
        p_text[i].set_y(-0.8)
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
    if i==6:
#         L_text[i].set_y(1.1)
        p_text[i].set_y(-0.45)
# #         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2WW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})    

for t in L_text:
    t.set_size(35)
    
# for i in range(len(p_text)):
# #     if i==2:
# #         p_text[i].set_y(0.65)
# #         L_text[i].set_x(0.2)
# #         L_text[i].set_y(1.1)
#     if i==6:
# #         L_text[i].set_y(1.1)
#         p_text[i].set_y(-0.3)
# #         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2WL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==6:
#         L_text[i].set_y(1.1)
        p_text[i].set_y(-0.3)
#         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2LW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})    

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==5:
        p_text[i].set_y(-0.6)
        L_text[i].set_x(-0.1)
        L_text[i].set_y(-1.2)
    if i==7:
        L_text[i].set_y(-0.3)
        p_text[i].set_y(-0.15)
    if i==8:
#         L_text[i].set_y(-0.3)
        p_text[i].set_x(0.9)
        p_text[i].set_y(-0.05)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY2LL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})   

for t in L_text:
    t.set_size(35)
    
# for i in range(len(p_text)):
# #     if i==2:
# #         p_text[i].set_y(0.65)
# #         L_text[i].set_x(0.2)
# #         L_text[i].set_y(1.1)
#     if i==6:
#         L_text[i].set_x(0.3)
#         L_text[i].set_y(-1.2)
#         p_text[i].set_y(-0.7)
#         p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3WW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
        p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3WL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})   

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==6:
#         L_text[i].set_y(1.7)
#         p_text[i].set_y(0.45)
        p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3LW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==2:
#         L_text[i].set_y(1.7)
        p_text[i].set_y(0.45)
#         p_text[i].set_x(0.4)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY3LL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})   

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
        p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4WW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
        p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4WL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==2:
        p_text[i].set_y(0.65)
        L_text[i].set_x(0.2)
        L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4LW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==2:
        p_text[i].set_y(0.65)
        L_text[i].set_x(0.2)
        L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY4LL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5WW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# alldicttest['Defensive_short']

sisize
# Out:
# 0.9989999999999999

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})    

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==2:
        p_text[i].set_y(0.65)
        L_text[i].set_x(0.2)
        L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5WL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
#     if i==2:
#         p_text[i].set_y(0.65)
#         L_text[i].set_x(0.2)
#         L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5LW_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊

# %%
# labels=['Defensive_short','Dribble','Drop','Clear','Net_smash','Net_lift','Smash','Drive','Net']
labels=['Ds','Db','Dr','Cl','Ns','Nl','Sm','Dri','N']
size=[alldicttest['Defensive_short'],alldicttest['Dribble'],alldicttest['Drop'],alldicttest['Clear'],alldicttest['Net_smash'],alldicttest['Net_lift'],alldicttest['Smash'],alldicttest['Drive'],alldicttest['Net']]
# colors=['chocolate','r','darkorange','y','forestgreen','royalblue','c','orchid','pink']
colors=['dimgray','gray','darkgray','silver','lightgrey','grey','whitesmoke','darkgrey','lightgray']
plt.figure(figsize=(6,6))
# alldicttest[]
patch,L_text,p_text=plt.pie(size,                           # 數值
        labels = labels,                # 標籤
        autopct = "%1.1f%%",            # 將數值百分比並留到小數點一位
        pctdistance = 0.6,              # 數字距圓心的距離
        colors=colors,
        textprops = {"fontsize" : 25})  

for t in L_text:
    t.set_size(35)
    
for i in range(len(p_text)):
    if i==2:
        p_text[i].set_y(0.65)
        L_text[i].set_x(0.2)
        L_text[i].set_y(1.1)
    if i==6:
        L_text[i].set_x(0.3)
        L_text[i].set_y(-1.2)
        p_text[i].set_y(-0.7)
#         p_text[i].set_x(-0.1)


plt.axis('equal')                                          # 使圓餅圖比例相等
# plt.legend(loc = "best") 
# plt.title("TOKYO_2(server:winner=Tai:Tai)", {"fontsize" : 35})  # 設定標題及其文字大小
plt.savefig("20230410NEWPIC/HSBCDAY5LL_1b.jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊
